# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import math

cgtd0 = np.array([4E5, 3.5E5, 5E5, 4E5, 3E5, 3E5, 3.5E5]) #!!
bd0 = np.array([7E5, 5E5, 4E5, 8E5])

c1d4 = np.array([22E5, 36E5, 35E5, 33E5])
c2d4 = np.array([43E5, 32E5, 26E5, 34E5])
c3d4 = np.array([18E5, 9E5, 22E5, 26E5])
g4d4 = np.array([9E8, 7E8, 7E8, 9E8])
g5d4 = np.array([13E8, 5E8, 10E8, 7E8])
g6d4 = np.array([18E8, 9E8, 12E8, 14E8])
t7d4 = np.array([11E5, 3E5, 12E5, 11E5])
t8d4 = np.array([20E5, 12E5, 9E5, 16E5])
t9d4 = np.array([14E5, 5E5, 3E5, 9E5])

c1d5 = np.array([21E5, 21E5, 9E5, 20E5])
c2d5 = np.array([61E5, 52E5, 43E5, 55E5])
c3d5 = np.array([18E5, 22E5, 25E5, 24E5])
g4d5 = np.array([17E8, 26E8, 17E8, 19E8])
g5d5 = np.array([27E8, 24E8, 16E8]) #!!
g6d5 = np.array([37E8, 40E8, 31E8, 22E8])
t7d5 = np.array([13E5, 18E5, 14E5, 11E5])
t8d5 = np.array([24E5, 31E5, 36E5, 31E5])
t9d5 = np.array([20E5, 26E5, 16E5, 27E5])

c1d7 = np.array([112E5, 114E5, 93E5, 92E5])
c2d7 = np.array([np.nan, np.nan, np.nan, np.nan]) #overgrown
c3d7 = np.array([23E5, 22E5, 20E5, 25E5])
g4d7 = np.array([18E9, 15E9, 17E9, 21E9])
g5d7 = np.array([11E9, 7E9, 16E9, 11E9])
g6d7 = np.array([39E9, 44E9, 51E9, 44E9])
t7d7 = np.array([23E5, 38E5, 22E5, 19E5])
t8d7 = np.array([6E7, 4E7, 6E7, 7E7])
t9d7 = np.array([16E6, 14E6, 16E6, 16E6])

c1d11 = np.array([47E5, 52E5, 46E5, 54E5])
c2d11 = np.array([38E7, 41E7, 45E7, 42E7])
c3d11 = np.array([12E5, 11E5, 15E5, 8E5])
g4d11 = np.array([15E8, 20E8, 20E8, 17E8])
g5d11 = np.array([42E9, 36E9, 45E9, 32E9])
g6d11 = np.array([30E8, 24E8, 25E8, 27E8])
t7d11 = np.array([107E5, 89E5, 99E5, 85E5])
t8d11 = np.array([27E8, 20E8, 21E8, 24E8])
t9d11 = np.array([25E9, 16E9, 13E9, 32E9])
b10d4 = np.array([0, 0, 0, 0])
b11d4 = np.array([10E2, 15E2, 15E2, 14E2])
b12d4 = np.array([29E6, 29E6, 21E6, 19E6])

c1d13 = np.array([45E5, 42E5, 42E5, 44E5])
c2d13 = np.array([12E8, 11E8, 9E8, 8E8])
c3d13 = np.array([9E5, 10E5, 6E5, 14E5])
g4d13 = np.array([9E9, 6E9, 14E9, 10E9])
g5d13 = np.array([19E8, 33E8, 33E8, 32E8])
g6d13 = np.array([46E8, 43E8, 53E8, 49E8])
t7d13 = np.array([11E7, 5E7, 10E7, 12E7])
t8d13 = np.array([27E9, 23E9, 27E9, 20E9])
t9d13 = np.array([84E9, 104E9, 99E9, 82E9])
b10d6 = np.array([0, 0, 0, 0])
b11d6 = np.array([27E4, 29E4, 25E4, 22E4])
b12d6 = np.array([48E6, 42E6, 54E6, 58E6])

c1d15 = np.array([33E5, 46E5, 32E5, 49E5])
c2d15 = np.array([5E8, 4E8, 11E8, 8E8])
c3d15 = np.array([13E5, 12E5, 14E5, 9E5])
g4d15 = np.array([10E9, 11E9, 8E9, 10E9])
g5d15 = np.array([77E9, 72E9, 59E9, 63E9])
g6d15 = np.array([43E8, 20E8, 38E8, 27E8])
t7d15 = np.array([20E8, 19E8, 16E8, 21E8])
t8d15 = np.array([7E8, 13E8, 9E8, 10E8])
t9d15 = np.array([65E9, 56E9, 46E9, 57E9])
b10d8 = np.array([0, 0, 0, 0])
b11d8 = np.array([12E6, 13E6, 10E6, 15E6])
b12d8 = np.array([26E6, 26E6, 22E6, 21E6])

c1d18 = np.array([59E5, 53E5, 51E5, 63E5])
c2d18 = np.array([56E7]) #!!
c3d18 = np.array([10E5, 7E5, 7E5, 9E5])
g4d18 = np.array([168E7, 153E7, 162E7, 186E7])
g5d18 = np.array([49E8, 15E8, 19E8, 14E8])
g6d18 = np.array([27E8, 33E8, 36E8, 14E8])
t7d18 = np.array([44E8, 57E8, 48E8, 49E8])
t8d18 = np.array([25E8, 21E8, 21E8, 23E8])
t9d18 = np.array([60E9, 59E9, 57E9, 57E9])
b10d11 = np.array([0, 0, 0, 0])
b11d11 = np.array([7E7, 7E7, 10E7, 2E7])
b12d11 = np.array([38E7, 37E7, 25E7, 42E7])

c1d20 = np.array([13E6, 13E6, 9E6, 11E6])
c2d20 = np.array([9E9, 6E9, 7E9, 3E9])
c3d20 = np.array([14E5, 10E5, 13E5, 9E5])
g4d20 = np.array([43E9, 44E9, 38E9, 39E9])
g5d20 = np.array([37E9, 34E9, 40E9, 36E9])
g6d20 = np.array([3E9, 10E9, 8E9, 6E9])
t7d20 = np.array([86E9, 84E9, 111E9, 97E9])
t8d20 = np.array([59E9, 49E9, 53E9, 52E9])
t9d20 = np.array([189E9, 182E9, 174E9, 169E9])
b10d13 = np.array([0, 0, 0, 0])
b11d13 = np.array([20E8, 16E8, 12E8, 9E8])
b12d13 = np.array([8E8, 11E8, 9E8, 6E8])

c1d32 = np.array([7E7, 8E7, 6E7, 5E7])
c2d32 = np.array([17E8, 9E8, 11E8, 17E8])
c3d32 = np.array([28E5, 30E5, 19E5, 23E5])
g4d32 = np.array([8E9, 7E9, 13E9, 8E9])
g5d32 = np.array([27E9, 33E9, 25E9, 21E9])
g6d32 = np.array([8E9, 6E9, 6E9, 6E9])
t7d32 = np.array([32E9, 29E9, 41E9, 41E9])
t8d32 = np.array([19E8, 16E8, 30E8, 14E8])
t9d32 = np.array([22E9, 27E9, 25E9, 34E9])
b10d25 = np.array([0, 0, 0, 0])
b11d25 = np.array([19E6, 23E6, 23E6, 26E6])
b12d25 = np.array([3E6, 7E6, 5E6, 4E6])

c1d46 = np.array([15E6, 9E6, 6E6, 11E6])
c2d46 = np.array([10E8, 11E8, 8E8, 6E8])
c3d46 = np.array([67E6, 58E6, 66E6, 56E6])
g4d46 = np.array([196E8, 180E8, 171E8, 182E8])
g5d46 = np.array([81E9, 85E9, 94E9, 105E9])
g6d46 = np.array([227E9, 206E9, 231E9, 231E9])
t7d46 = np.array([281E7, 252E7, 246E7, 261E7])
t8d46 = np.array([158E9, 161E9, 153E9, 147E9])
t9d46 = np.array([265E7, 267E7, 284E7, 249E7])
b10d39 = np.array([0, 0, 0, 0])
b11d39 = np.array([50E7, 39E7, 37E7, 29E7])
b12d39 = np.array([9E5, 7E5, 5E5, 11E5])

#mod

cgtd0_mean = np.mean(cgtd0)
bd0_mean = np.mean(bd0)

c1d4_mean = np.mean(c1d4)
c2d4_mean = np.mean(c2d4)
c3d4_mean = np.mean(c3d4)
c1d5_mean = np.mean(c1d5)
c2d5_mean = np.mean(c2d5)
c3d5_mean = np.mean(c3d5)
c1d7_mean = np.mean(c1d7)
c2d7_mean = np.mean(c2d7)
c3d7_mean = np.mean(c3d7)
c1d11_mean = np.mean(c1d11)
c2d11_mean = np.mean(c2d11)
c3d11_mean = np.mean(c3d11)
c1d13_mean = np.mean(c1d13)
c2d13_mean = np.mean(c2d13)
c3d13_mean = np.mean(c3d13)
c1d15_mean = np.mean(c1d15)
c2d15_mean = np.mean(c2d15)
c3d15_mean = np.mean(c3d15)
c1d18_mean = np.mean(c1d18)
c2d18_mean = np.mean(c2d18)
c3d18_mean = np.mean(c3d18)
c1d20_mean = np.mean(c1d20)
c2d20_mean = np.mean(c2d20)
c3d20_mean = np.mean(c3d20)
c1d32_mean = np.mean(c1d32)
c2d32_mean = np.mean(c2d32)
c3d32_mean = np.mean(c3d32)
c1d46_mean = np.mean(c1d46)
c2d46_mean = np.mean(c2d46)
c3d46_mean = np.mean(c3d46)
#mod

g4d4_mean = np.mean(g4d4)
g5d4_mean = np.mean(g5d4)
g6d4_mean = np.mean(g6d4)
g4d5_mean = np.mean(g4d5)
g5d5_mean = np.mean(g5d5)
g6d5_mean = np.mean(g6d5)
g4d7_mean = np.mean(g4d7)
g5d7_mean = np.mean(g5d7)
g6d7_mean = np.mean(g6d7)
g4d11_mean = np.mean(g4d11)
g5d11_mean = np.mean(g5d11)
g6d11_mean = np.mean(g6d11)
g4d13_mean = np.mean(g4d13)
g5d13_mean = np.mean(g5d13)
g6d13_mean = np.mean(g6d13)
g4d15_mean = np.mean(g4d15)
g5d15_mean = np.mean(g5d15)
g6d15_mean = np.mean(g6d15)
g4d18_mean = np.mean(g4d18)
g5d18_mean = np.mean(g5d18)
g6d18_mean = np.mean(g6d18)
g4d20_mean = np.mean(g4d20)
g5d20_mean = np.mean(g5d20)
g6d20_mean = np.mean(g6d20)
g4d32_mean = np.mean(g4d32)
g5d32_mean = np.mean(g5d32)
g6d32_mean = np.mean(g6d32)
g4d46_mean = np.mean(g4d46)
g5d46_mean = np.mean(g5d46)
g6d46_mean = np.mean(g6d46)
#mod

t7d4_mean = np.mean(t7d4)
t8d4_mean = np.mean(t8d4)
t9d4_mean = np.mean(t9d4)
t7d5_mean = np.mean(t7d5)
t8d5_mean = np.mean(t8d5)
t9d5_mean = np.mean(t9d5)
t7d7_mean = np.mean(t7d7)
t8d7_mean = np.mean(t8d7)
t9d7_mean = np.mean(t9d7)
t7d11_mean = np.mean(t7d11)
t8d11_mean = np.mean(t8d11)
t9d11_mean = np.mean(t9d11)
t7d13_mean = np.mean(t7d13)
t8d13_mean = np.mean(t8d13)
t9d13_mean = np.mean(t9d13)
t7d15_mean = np.mean(t7d15)
t8d15_mean = np.mean(t8d15)
t9d15_mean = np.mean(t9d15)
t7d18_mean = np.mean(t7d18)
t8d18_mean = np.mean(t8d18)
t9d18_mean = np.mean(t9d18)
t7d20_mean = np.mean(t7d20)
t8d20_mean = np.mean(t8d20)
t9d20_mean = np.mean(t9d20)
t7d32_mean = np.mean(t7d32)
t8d32_mean = np.mean(t8d32)
t9d32_mean = np.mean(t9d32)
t7d46_mean = np.mean(t7d46)
t8d46_mean = np.mean(t8d46)
t9d46_mean = np.mean(t9d46)
#mod

b10d4_mean = np.mean(b10d4)
b11d4_mean = np.mean(b11d4)
b12d4_mean = np.mean(b12d4)
b10d6_mean = np.mean(b10d6)
b11d6_mean = np.mean(b11d6)
b12d6_mean = np.mean(b12d6)
b10d8_mean = np.mean(b10d8)
b11d8_mean = np.mean(b11d8)
b12d8_mean = np.mean(b12d8)
b10d11_mean = np.mean(b10d11)
b11d11_mean = np.mean(b11d11)
b12d11_mean = np.mean(b12d11)
b10d13_mean = np.mean(b10d13)
b11d13_mean = np.mean(b11d13)
b12d13_mean = np.mean(b12d13)
b10d25_mean = np.mean(b10d25)
b11d25_mean = np.mean(b11d25)
b12d25_mean = np.mean(b12d25)
b10d39_mean = np.mean(b10d39)
b11d39_mean = np.mean(b11d39)
b12d39_mean = np.mean(b12d39)
#mod

# %%
c1 = np.array([cgtd0_mean, 3.15E6, 1.775E6, 1.0275E7, 4.975E6, 4.325E6, 4.0E6, 5.56E6, 1.15E7, 6E7, c1d46_mean]) #mod
c1n = c1/cgtd0_mean
c2 = np.array([cgtd0_mean, 3.375E6, 5.275E6, np.nan, 4.175E8, 1.0E9, 7.0E8, 5.6E8, 6.25E9, 1.35E9, c2d46_mean]) #np.nan --> overgrown #mod            c2d18 n=1
c2n = c2/cgtd0_mean
#print((np.log10(c2[2])+np.log10(c2[4])))
#c2_interpolatedish = np.array([3.646E5, 3.375E6, 5.275E6, 15.342878943789351E6, 4.175E8])
c3 = np.array([cgtd0_mean, 1.875E6, 2.225E6, 2.25E6, 1.15E6, 9.75E5, 1.2E6, 8.25E5, 1.15E6, 2.5E6, c3d46_mean]) #mod
c3n = c3/cgtd0_mean

g4 = np.array([cgtd0_mean, 8.0E8, 1.975E9, 1.775E10, 1.8E9, 9.75E9, 9.75E9, 1.6725E9, 4.1E10, 9E9, g4d46_mean]) #mod
g4n = g4/cgtd0_mean
g5 = np.array([cgtd0_mean, 8.75E8, 2.233333333E9, 1.125E10, 3.875E10, 2.925E9, 6.775E10, 2.425E9, 3.675E10, 2.65E10, g5d46_mean]) #mod        g5d5 n=3
g5n = g5/cgtd0_mean
g6 = np.array([cgtd0_mean, 1.325E9, 3.25E9, 4.45E10, 2.65E9, 4.775E9, 3.4E9, 2.75E9, 6.75E9, 6.5E9, g6d46_mean]) #mod
g6n = g6/cgtd0_mean

t7 = np.array([cgtd0_mean, 9.25E5, 1.4E6, 2.55E6, 9.5E6, 9.5E7, 1.9E9, 4.95E9, 9.45E10, 3.575E10, t7d46_mean]) #mod
t7n = t7/cgtd0_mean
t8 = np.array([cgtd0_mean, 1.275E6, 3.05E6, 5.75E7, 2.3E9, 2.425E10, 9.75E9, 2.25E9, 5.325E10, 1.975E9, t8d46_mean]) #mod
t8n = t8/cgtd0_mean
t9 = np.array([cgtd0_mean, 7.75E5, 2.225E6, 1.55E7, 2.15E10, 9.225E10, 5.6E10, 5.825E10, 1.785E11, 2.7E10, t9d46_mean]) #mod
t9n = t9/cgtd0_mean

b10 = np.array([bd0_mean, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]) #np.nan(s) --> No cells present #mod
b10n = b10/bd0_mean
b11 = np.array([bd0_mean, 1.35E3, 2.575E5, 1.25E7, 6.5E7, 1.425E9, 2.275E7, b11d39_mean]) #mod
b11n = b11/bd0_mean
b12 = np.array([bd0_mean, 2.45E7, 5.05E7, 2.375E7, 3.55E8, 8.5E8, 4.75E6, b12d39_mean]) #mod
b12n = b12/bd0_mean

# %%
import statistics

#c_matrix = np.column_stack((c1,c2,c3))
#c_matrix[3][1] = np.nan
#c_matrix_adj = np.column_stack((c1,c3))
#g_matrix = np.column_stack((g4,g5,g6))
#t_matrix = np.column_stack((t7,t8,t9))
#b_matrix = np.column_stack((b10,b11,b12))
#b_matrix[1][0] = 0
#b_matrix[2][0] = 0
#b_matrix[3][0] = 0
#b_matrix[4][0] = 0
#b_matrix[5][0] = 0
#mod (if new b10=0)
#b_matrix_adj = np.column_stack((b11,b12))
#print(b_matrix)
#print(c_matrix)
#print(c_matrix[0])

#print(b_matrix)

day0_stdev = np.std(cgtd0)
day0_b_stdev = np.std(bd0)

day_0_sem = day0_stdev/(7**0.5)
day_0_b_sem = day0_b_stdev/(4**0.5)
print(day0_stdev)
print(day0_b_stdev)


stdev_c1 = np.array([day0_stdev, np.std(c1d4), np.std(c1d5), np.std(c1d7), np.std(c1d11), np.std(c1d13), np.std(c1d15), np.std(c1d18), np.std(c1d20), np.std(c1d32), np.std(c1d46)])
stdev_c2 = np.array([day0_stdev, np.std(c2d4), np.std(c2d5), np.std(c2d7), np.std(c2d11), np.std(c2d13), np.std(c2d15), np.std(c2d18), np.std(c2d20), np.std(c2d32), np.std(c2d46)])
stdev_c3 = np.array([day0_stdev, np.std(c3d4), np.std(c3d5), np.std(c3d7), np.std(c3d11), np.std(c3d13), np.std(c3d15), np.std(c3d18), np.std(c3d20), np.std(c3d32), np.std(c3d46)])

stdev_g4 = np.array([day0_stdev, np.std(g4d4), np.std(g4d5), np.std(g4d7), np.std(g4d11), np.std(g4d13), np.std(g4d15), np.std(g4d18), np.std(g4d20), np.std(g4d32), np.std(g4d46)])
stdev_g5 = np.array([day0_stdev, np.std(g5d4), np.std(g5d5), np.std(g5d7), np.std(g5d11), np.std(g5d13), np.std(g5d15), np.std(g5d18), np.std(g5d20), np.std(g5d32), np.std(g5d46)])
stdev_g6 = np.array([day0_stdev, np.std(g6d4), np.std(g6d5), np.std(g6d7), np.std(g6d11), np.std(g6d13), np.std(g6d15), np.std(g6d18), np.std(g6d20), np.std(g6d32), np.std(g6d46)])

stdev_t7 = np.array([day0_stdev, np.std(t7d4), np.std(t7d5), np.std(t7d7), np.std(t7d11), np.std(t7d13), np.std(t7d15), np.std(t7d18), np.std(t7d20), np.std(t7d32), np.std(t7d46)])
stdev_t8 = np.array([day0_stdev, np.std(t8d4), np.std(t8d5), np.std(t8d7), np.std(t8d11), np.std(t8d13), np.std(t8d15), np.std(t8d18), np.std(t8d20), np.std(t8d32), np.std(t8d46)])
stdev_t9 = np.array([day0_stdev, np.std(t9d4), np.std(t9d5), np.std(t9d7), np.std(t9d11), np.std(t9d13), np.std(t9d15), np.std(t9d18), np.std(t9d20), np.std(t9d32), np.std(t9d46)])

stdev_b10 = np.array([day0_b_stdev, np.std(b10d4), np.std(b10d6), np.std(b10d8), np.std(b10d11), np.std(b10d13), np.std(b10d25), np.std(b10d39)])
stdev_b11 = np.array([day0_b_stdev, np.std(b11d4), np.std(b11d6), np.std(b11d8), np.std(b11d11), np.std(b11d13), np.std(b11d25), np.std(b11d39)])
stdev_b12 = np.array([day0_b_stdev, np.std(b12d4), np.std(b12d6), np.std(b12d8), np.std(b12d11), np.std(b12d13), np.std(b12d25), np.std(b12d39)])

#mod all of above

sem_c1 = stdev_c1/(4**0.5)
sem_c2 = stdev_c2/(4**0.5)
sem_c2[7] = stdev_c2[7]/(1**0.5)
sem_c3 = stdev_c3/(4**0.5)
sem_g4 = stdev_g4/(4**0.5)
sem_g5 = stdev_g5/(4**0.5)
sem_g5[2] = stdev_g5[2]/(3**0.5)
print(sem_g5, stdev_g5)
sem_g6 = stdev_g6/(4**0.5)
sem_t7 = stdev_t7/(4**0.5)
sem_t8 = stdev_t8/(4**0.5)
sem_t9 = stdev_t9/(4**0.5)
sem_b10 = stdev_b10/(4**0.5)
sem_b11 = stdev_b11/(4**0.5)
sem_b12 = stdev_b12/(4**0.5)

sem_c1_n = sem_c1/cgtd0_mean
sem_c2_n = sem_c2/cgtd0_mean
sem_c3_n = sem_c3/cgtd0_mean
sem_g4_n = sem_g4/cgtd0_mean
sem_g5_n = sem_g5/cgtd0_mean
sem_g6_n = sem_g6/cgtd0_mean
sem_t7_n = sem_t7/cgtd0_mean
sem_t8_n = sem_t8/cgtd0_mean
sem_t9_n = sem_t9/cgtd0_mean
sem_b10_n = sem_b10/bd0_mean
sem_b11_n = sem_b11/bd0_mean
sem_b12_n = sem_b12/bd0_mean

print('stdev c1', np.shape(stdev_c1), stdev_c1)
print('sem c1', np.shape(sem_c1), sem_c1)
print('sem_n c1', np.shape(sem_c1_n), sem_c1_n)
# Out:
# 64681.32241526726
# 158113.88300841895
# [3.23406612e+04 1.51554446e+08 2.68051957e+08 1.59589317e+09
#  2.53414187e+09 2.96595263e+08 3.55975772e+09 7.20568352e+08
#  1.08253175e+09 2.16506351e+09 4.61485374e+09] [6.46813224e+04 3.03108891e+08 4.64279609e+08 3.19178633e+09
#  5.06828373e+09 5.93190526e+08 7.11951543e+09 1.44113670e+09
#  2.16506351e+09 4.33012702e+09 9.22970747e+09]
# stdev c1 (11,) [   64681.32241527   559016.99437495   506828.37331783  1028044.2597476
#    334477.20400649   129903.81056767   758287.54440516   476969.60070847
#   1658312.3951777  11180339.88749895  3269174.20765551]
# sem c1 (11,) [  32340.66120763  279508.49718747  253414.18665892  514022.1298738
#   167238.60200325   64951.90528383  379143.77220258  238484.80035424
#   829156.19758885 5590169.94374947 1634587.10382775]
# sem_n c1 (11,) [ 0.08707101  0.75252288  0.68226896  1.38390573  0.45025777  0.17487051
#   1.02077169  0.64207446  2.23234361 15.05045754  4.40081143]

# %%
day = np.array([0, 4, 5, 7, 11, 13, 15, 18, 20, 32, 46]) #mod
day_b = np.array([0, 4, 6, 8, 11, 13, 25, 39]) #mod

plt.figure(figsize=(10, 8))
plt.semilogy(day, c1n, label="c1", color="#FF0000")
plt.errorbar(day, c1n, yerr=sem_c1_n, fmt='o', capsize=5, color="#FF0000", alpha=0.4)
plt.semilogy(day, c2n, label="c2, d7=overgrown", color="#AA0000")
plt.errorbar(day, c2n, yerr=sem_c2_n, fmt='o', capsize=5, color="#AA0000", alpha=0.4)
plt.semilogy(day, c3n, label="c3", color="#660000")
plt.errorbar(day, c3n, yerr=sem_c3_n, fmt='o', capsize=5, color="#660000", alpha=0.4)

plt.semilogy(day, g4n, label="g4", color="#00FF00")
plt.errorbar(day, g4n, yerr=sem_g4_n, fmt='o', capsize=5, color="#00FF00", alpha=0.4)
plt.semilogy(day, g5n, label="g5", color="#00AA00")
plt.errorbar(day, g5n, yerr=sem_g5_n, fmt='o', capsize=5, color="#00AA00", alpha=0.4)
plt.semilogy(day, g6n, label="g6", color="#006600")
plt.errorbar(day, g6n, yerr=sem_g6_n, fmt='o', capsize=5, color="#006600", alpha=0.4)

plt.semilogy(day, t7n, label="t7", color="#0000FF")
plt.errorbar(day, t7n, yerr=sem_t7_n, fmt='o', capsize=5, color="#0000FF", alpha=0.4)
plt.semilogy(day, t8n, label="t8", color="#0000AA")
plt.errorbar(day, t8n, yerr=sem_t8_n, fmt='o', capsize=5, color="#0000AA", alpha=0.4)
plt.semilogy(day, t9n, label="t9", color="#000066")
plt.errorbar(day, t9n, yerr=sem_t9_n, fmt='o', capsize=5, color="#000066", alpha=0.4)

plt.semilogy(day_b, b10n, label="b10, d4/6/8/11/13/25/39 = 0", color="#FF00FF") #mod (label)
plt.semilogy(0, b10n[0], 'o', color="#FF00FF")
plt.errorbar(day_b, b10n, yerr=sem_b10_n, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)
plt.semilogy(day_b, b11n, label="b11", color="#AA00AA")
plt.errorbar(day_b, b11n, yerr=sem_b11_n, fmt='o', capsize=5, color="#AA00AA", alpha=0.4)
plt.semilogy(day_b, b12n, label="b12", color="#660066")
plt.errorbar(day_b, b12n, yerr=sem_b12_n, fmt='o', capsize=5, color="#660066", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("what is happening")
plt.legend(loc='upper left')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))

axs[0, 0].plot(day, c1, label="c1", color="#FF0000")
#axs[0, 0].plot(day, c2, label="c2, d7=overgrown", color="#AA0000")
axs[0, 0].plot(day, c3, label="c3", color="#660000")
axs[0, 0].set_title("control")
axs[0, 0].errorbar(day, c1, yerr=sem_c1, fmt='o', capsize=5, color="#FF0000", alpha=0.4)
axs[0, 0].errorbar(day, c3, yerr=sem_c3, fmt='o', capsize=5, color="#660000", alpha=0.4)

axs[1, 0].plot(day, g4, label="g4", color="#00FF00")
axs[1, 0].plot(day, g5, label="g5", color="#00AA00")
axs[1, 0].plot(day, g6, label="g6", color="#006600")
axs[1, 0].set_title("glucose")
axs[1, 0].errorbar(day, g4, yerr=sem_g4, fmt='o', capsize=5, color="#00FF00", alpha=0.4)
axs[1, 0].errorbar(day, g5, yerr=sem_g5, fmt='o', capsize=5, color="#00AA00", alpha=0.4)
axs[1, 0].errorbar(day, g6, yerr=sem_g6, fmt='o', capsize=5, color="#006600", alpha=0.4)

axs[0, 1].plot(day, t7, label="t7", color="#0000FF")
axs[0, 1].plot(day, t8, label="t8", color="#0000AA")
axs[0, 1].plot(day, t9, label="t9", color="#000066")
axs[0, 1].set_title("tholins")
axs[0, 1].errorbar(day, t7, yerr=sem_t7, fmt='o', capsize=5, color="#0000FF", alpha=0.4)
axs[0, 1].errorbar(day, t8, yerr=sem_t8, fmt='o', capsize=5, color="#0000AA", alpha=0.4)
axs[0, 1].errorbar(day, t9, yerr=sem_t9, fmt='o', capsize=5, color="#000066", alpha=0.4)

axs[1, 1].plot(day_b, b10, label="b10, d4=0 d6=0", color="#FF00FF")
axs[1, 1].plot(day_b, (b10[0], 0, 0, 0, 0, 0, 0, 0), color="#FF00FF") #mod
axs[1, 1].plot(day_b, b11, label="b11", color="#AA00AA")
axs[1, 1].plot(day_b, b12, label="b12", color="#660066")
axs[1, 1].set_title("baked moon")
axs[1, 1].errorbar(day_b, b10, yerr=sem_b10, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)
axs[1, 1].errorbar(day_b, b11, yerr=sem_b11, fmt='o', capsize=5, color="#AA00AA", alpha=0.4)
axs[1, 1].errorbar(day_b, b12, yerr=sem_b12, fmt='o', capsize=5, color="#660066", alpha=0.4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def mean_of_arrays (a,b,c):
    mean_arr = np.array([(a[i]+b[i]+c[i])/3 for i in range (len(a))])
    return mean_arr

def mean_of_arrays_adj (a,b):
    mean_arr_adj = np.array([(a[i]+b[i])/2 for i in range (len(a))])
    return mean_arr_adj

c_mean = mean_of_arrays(c1,c2,c3)
c_mean[3] = (c1[3]+c3[3])/2
c_mean_n = c_mean/cgtd0_mean
c_mean_adj = mean_of_arrays_adj(c1,c3)
c_mean_n_adj = c_mean_adj/cgtd0_mean

g_mean = mean_of_arrays(g4,g5,g6)
g_mean_n = g_mean/cgtd0_mean

t_mean = mean_of_arrays(t7,t8,t9)
t_mean_n = t_mean/cgtd0_mean

b_mean = mean_of_arrays(b10,b11,b12)
b_mean[1] = (0+b11[1]+b12[1])/3
b_mean[2] = (0+b11[2]+b12[2])/3
b_mean[3] = (0+b11[3]+b12[3])/3
b_mean[4] = (0+b11[4]+b12[4])/3
b_mean[5] = (0+b11[5]+b12[5])/3
b_mean[6] = (0+b11[6]+b12[6])/3
b_mean[7] = (0+b11[7]+b12[7])/3
#mod (if new b10 is still 0)
b_mean_n = b_mean/bd0_mean
b_mean_adj = mean_of_arrays_adj(b11,b12)
b_mean_n_adj = b_mean_adj/bd0_mean

print(c_mean, g_mean, t_mean, b_mean)
# Out:
# [3.71428571e+05 2.80000000e+06 3.09166667e+06 6.26250000e+06
#  1.41208333e+08 3.35100000e+08 2.35066667e+08 1.88795000e+08
#  2.08755000e+09 4.70833333e+08 3.15666667e+08] [3.71428571e+05 1.00000000e+09 2.48611111e+09 2.45000000e+10
#  1.44000000e+10 5.81666667e+09 2.69666667e+10 2.28250000e+09
#  2.81666667e+10 1.40000000e+10 1.11075000e+11] [3.71428571e+05 9.91666667e+05 2.22500000e+06 2.51833333e+07
#  7.93650000e+09 3.88650000e+10 2.25500000e+10 2.18166667e+10
#  1.08750000e+11 2.15750000e+10 5.33375000e+10] [6.00000000e+05 8.16711667e+06 1.69191667e+07 1.20833333e+07
#  1.40000000e+08 7.58333333e+08 9.16666667e+06 1.29433333e+08]

# %%
cd4_comb = np.concatenate((c1d4, c2d4, c3d4))
cd5_comb = np.concatenate((c1d5, c2d5, c3d5))
cd7_comb = np.concatenate((c1d7, c2d7, c3d7))
cd11_comb = np.concatenate((c1d11, c2d11, c3d11))
cd13_comb = np.concatenate((c1d13, c2d13, c3d13))
cd15_comb = np.concatenate((c1d15, c2d15, c3d15))
cd18_comb = np.concatenate((c1d18, c2d18, c3d18))
cd20_comb = np.concatenate((c1d20, c2d20, c3d20))
cd32_comb = np.concatenate((c1d32, c2d32, c3d32))
cd46_comb = np.concatenate((c1d46, c2d46, c3d46))

#mod

cd4_comb_adj = np.concatenate((c1d4, c3d4))
cd5_comb_adj = np.concatenate((c1d5, c3d5))
cd7_comb_adj = np.concatenate((c1d7, c3d7))
cd11_comb_adj = np.concatenate((c1d11, c3d11))
cd13_comb_adj = np.concatenate((c1d13, c3d13))
cd15_comb_adj = np.concatenate((c1d15, c3d15))
cd18_comb_adj = np.concatenate((c1d18, c3d18))
cd20_comb_adj = np.concatenate((c1d20, c3d20))
cd32_comb_adj = np.concatenate((c1d32, c3d32))
cd46_comb_adj = np.concatenate((c1d46, c3d46))

#mod

print('stdev_g5', stdev_g5, stdev_g6[2])
g4d5_max = g4d5 + stdev_g4[2]
g4d5_min = g4d5 - stdev_g4[2]
g5d5_max = g5d5 + stdev_g5[2]
g5d5_min = g5d5 - stdev_g5[2]
g6d5_max = g6d5 + stdev_g6[2]
g6d5_min = g6d5 - stdev_g6[2]
print(g5d5, g5d5_max)

c1d18_max = c1d18 + stdev_c1[7]
c1d18_min = c1d18 - stdev_c1[7]
c2d18_max = c2d18 + stdev_c2[7]
c2d18_min = c2d18 - stdev_c2[7]
c3d18_max = c3d18 + stdev_c3[7]
c3d18_min = c3d18 - stdev_c3[7]

gd4_comb = np.concatenate((g4d4, g5d4, g6d4))
gd5_comb = np.concatenate((g4d5, g5d5, g6d5))    #g5d5 n=3

g4d5_mean_max = np.mean(g4d5_max)
g4d5_mean_min = np.mean(g4d5_min)
g5d5_mean_max = np.mean(g5d5_max)
g5d5_mean_min = np.mean(g5d5_min)
g6d5_mean_max = np.mean(g6d5_max)
g6d5_mean_min = np.mean(g6d5_min)

c1d18_mean_max = np.mean(c1d18_max)
c1d18_mean_min = np.mean(c1d18_min)
c2d18_mean_max = np.mean(c2d18_max)
c2d18_mean_min = np.mean(c2d18_min)
c3d18_mean_max = np.mean(c3d18_max)
c3d18_mean_min = np.mean(c3d18_min)

gd5_mean_max = (g4d5_mean_max + g5d5_mean_max + g6d5_mean_max)/3
gd5_mean_min = (g4d5_mean_min + g5d5_mean_min + g6d5_mean_min)/3

cd18_mean_max = (c1d18_mean_max + c2d18_mean_max + c3d18_mean_max)/3
cd18_mean_min = (c1d18_mean_min + c2d18_mean_min + c3d18_mean_min)/3

stdev_cd18_max = np.std([c1d18_mean_max, c2d18_mean_max, c3d18_mean_max])
stdev_cd18_min = np.std([c1d18_mean_min, c2d18_mean_min, c3d18_mean_min])

stdev_gd5_max = np.std([g4d5_mean_max, g5d5_mean_max, g6d5_mean_max])
stdev_gd5_min = np.std([g4d5_mean_min, g5d5_mean_min, g6d5_mean_min])

print('stdev_max/min', stdev_gd5_max, stdev_gd5_min)

gd5_full_max = gd5_mean_max + stdev_gd5_max
gd5_full_min = gd5_mean_min - stdev_gd5_min
gd5_mean_check = np.mean([g4[2], g5[2], g6[2]])

cd18_full_max = cd18_mean_max + stdev_cd18_max
cd18_full_min = cd18_mean_min - stdev_cd18_min
cd18_mean_check = np.mean([c1[7], c2[7], c3[7]])

print('gd5:', gd5_full_max, gd5_full_min, gd5_mean_check)
gd5_stdev_new = (gd5_full_max - gd5_full_min)/2
cd18_stdev_new = (cd18_full_max - cd18_full_min)/2
print('gd5_stdev_new:', gd5_stdev_new)

gd7_comb = np.concatenate((g4d7, g5d7, g6d7))
gd11_comb = np.concatenate((g4d11, g5d11, g6d11))
gd13_comb = np.concatenate((g4d13, g5d13, g6d13))
gd15_comb = np.concatenate((g4d15, g5d15, g6d15))
gd18_comb = np.concatenate((g4d18, g5d18, g6d18))
gd20_comb = np.concatenate((g4d20, g5d20, g6d20))
gd32_comb = np.concatenate((g4d32, g5d32, g6d32))
gd46_comb = np.concatenate((g4d46, g5d46, g6d46))

#mod

td4_comb = np.concatenate((t7d4, t8d4, t9d4))
td5_comb = np.concatenate((t7d5, t8d5, t9d5))
td7_comb = np.concatenate((t7d7, t8d7, t9d7))
td11_comb = np.concatenate((t7d11, t8d11, t9d11))
td13_comb = np.concatenate((t7d13, t8d13, t9d13))
td15_comb = np.concatenate((t7d15, t8d15, t9d15))
td18_comb = np.concatenate((t7d18, t8d18, t9d18))
td20_comb = np.concatenate((t7d20, t8d20, t9d20))
td32_comb = np.concatenate((t7d32, t8d32, t9d32))
td46_comb = np.concatenate((t7d46, t8d46, t9d46))
#mod

bd4_comb = np.concatenate((b10d4, b11d4, b12d4))
bd6_comb = np.concatenate((b10d6, b11d6, b12d6))
bd8_comb = np.concatenate((b10d8, b11d8, b12d8))
bd11_comb = np.concatenate((b10d11, b11d11, b12d11))
bd13_comb = np.concatenate((b10d13, b11d13, b12d13))
bd25_comb = np.concatenate((b10d25, b11d25, b12d25))
bd39_comb = np.concatenate((b10d39, b11d39, b12d39))
#mod

print('???', np.shape(cd4_comb), cd4_comb)

stdev_c = np.array([day0_stdev, np.std(cd4_comb), np.std(cd5_comb), np.std(cd7_comb), np.std(cd11_comb), np.std(cd13_comb), np.std(cd15_comb), cd18_stdev_new, np.std(cd20_comb), np.std(cd32_comb), np.std(cd46_comb)])#mod
stdev_c_adj = np.array([day0_stdev, np.std(cd4_comb_adj), np.std(cd5_comb_adj), np.std(cd7_comb_adj), np.std(cd11_comb_adj), np.std(cd13_comb_adj), np.std(cd15_comb_adj), np.std(cd18_comb_adj), np.std(cd20_comb_adj), np.std(cd32_comb_adj), np.std(cd46_comb_adj)])#mod
stdev_g = np.array([day0_stdev, np.std(gd4_comb), gd5_stdev_new, np.std(gd7_comb), np.std(gd11_comb), np.std(gd13_comb), np.std(gd15_comb), np.std(gd18_comb), np.std(gd20_comb), np.std(gd32_comb), np.std(gd46_comb)])#mod
stdev_t = np.array([day0_stdev, np.std(td4_comb), np.std(td5_comb), np.std(td7_comb), np.std(td11_comb), np.std(td13_comb), np.std(td15_comb), np.std(td18_comb), np.std(td20_comb), np.std(td32_comb), np.std(td46_comb)])#mod
stdev_b = np.array([day0_b_stdev, np.std(bd4_comb), np.std(bd6_comb), np.std(bd8_comb), np.std(bd11_comb), np.std(bd13_comb), np.std(bd25_comb), np.std(bd39_comb)])#mod

sem_c = stdev_c/(12**0.5)
sem_c[0] = day_0_sem
sem_c[7] = stdev_c[7]/(3**0.5)
sem_c_adj = stdev_c_adj/(8**0.5)
sem_c_adj[0] = day_0_sem
sem_g = stdev_g/(12**0.5)   
sem_g[0] = day_0_sem
sem_g[2] = stdev_g[2]/(3**0.5)
sem_t = stdev_t/(12**0.5)
sem_t[0] = day_0_sem
sem_b = stdev_b/(12**0.5)
sem_b[0] = day_0_b_sem

sem_c_n = sem_c/cgtd0_mean
sem_c_n_adj = sem_c_adj/cgtd0_mean
sem_g_n = sem_g/cgtd0_mean
sem_t_n = sem_t/cgtd0_mean
sem_b_n = sem_b/bd0_mean

print('stdev_c', np.shape(stdev_c), stdev_c)
print('sem_c', np.shape(sem_c), sem_c)

print('stdev_g[2]:', stdev_g[2])
print('gd5_stdev_new:', gd5_stdev_new)


"""
c_matrix = np.column_stack((c1,c2,c3))
c_matrix[3][1] = np.nan
c_matrix_adj = np.column_stack((c1,c3))
g_matrix = np.column_stack((g4,g5,g6))
t_matrix = np.column_stack((t7,t8,t9))
b_matrix = np.column_stack((b10,b11,b12))
b_matrix[1][0] = 0
b_matrix[2][0] = 0
b_matrix[3][0] = 0
b_matrix[4][0] = 0
b_matrix[5][0] = 0
#mod (if new b10=0)
b_matrix_adj = np.column_stack((b11,b12))
print(b_matrix)
print(c_matrix)
#print(c_matrix[0])

#print(b_matrix)
"""
"""
day0_stdev = np.std([4.12E5, 3.167E5])
day0_b_stdev = np.std([bd0_mean])

day_0_sem = day0_stdev/(2**0.5)
day_0_b_sem = day0_b_stdev/(1**0.5)
print(day0_stdev)
print(day0_b_stdev)
"""

"""
#for i in len(c1):
stdev_c = np.column_stack((np.std(c_matrix[0]), np.std(c_matrix[1]), np.std(c_matrix[2]), np.std(c_matrix[3]), np.std(c_matrix[4]), np.std(c_matrix[5]), np.std(c_matrix[6]), np.std(c_matrix[7]), np.std(c_matrix[8]))) #mod
stdev_c[0][0] = day0_stdev
stdev_c[0][3] = np.std([c_matrix[3][0], c_matrix[3][2]])
stdev_c_n = stdev_c/cgtd0_mean
sem_c = stdev_c/(3**0.5)
sem_c[0][0] = day_0_sem
sem_c[0][3] = (sem_c[0][3]*(3**0.5))/(2**0.5)
sem_c_n = sem_c/cgtd0_mean

stdev_c_adj = np.column_stack((np.std(c_matrix_adj[0]), np.std(c_matrix_adj[1]), np.std(c_matrix_adj[2]), np.std(c_matrix_adj[3]), np.std(c_matrix_adj[4]), np.std(c_matrix_adj[5]), np.std(c_matrix_adj[6]), np.std(c_matrix_adj[7]), np.std(c_matrix_adj[8]))) #mod
stdev_c_adj[0][0] = day0_stdev
stdev_c_n_adj = stdev_c_adj/cgtd0_mean
sem_c_adj = stdev_c_adj/(3**0.5)
sem_c_adj[0][0] = day_0_sem
sem_c_n_adj = sem_c_adj/cgtd0_mean


print("stdev_c_n", stdev_c_n)
print("stdev_c_n/(3**0.5)", stdev_c_n/(3**0.5))
print("sem_c_n", sem_c_n)

stdev_g = np.column_stack((np.std(g_matrix[0]), np.std(g_matrix[1]), np.std(g_matrix[2]), np.std(g_matrix[3]), np.std(g_matrix[4]), np.std(g_matrix[5]), np.std(g_matrix[6]), np.std(g_matrix[7]), np.std(g_matrix[8]))) #mod
stdev_g[0][0] = day0_stdev
stdev_g_n = stdev_g/cgtd0_mean
sem_g = stdev_g/(3**0.5)
sem_g[0][0] = day_0_sem
sem_g_n = sem_g/cgtd0_mean

stdev_t = np.column_stack((np.std(t_matrix[0]), np.std(t_matrix[1]), np.std(t_matrix[2]), np.std(t_matrix[3]), np.std(t_matrix[4]), np.std(t_matrix[5]), np.std(t_matrix[6]), np.std(t_matrix[7]), np.std(t_matrix[8]))) #mod
stdev_t[0][0] = day0_stdev
stdev_t_n = stdev_t/cgtd0_mean
sem_t = stdev_t/(3**0.5)
sem_t[0][0] = day_0_sem
sem_t_n = sem_t/cgtd0_mean
print("stdev_t",stdev_t)

stdev_b = np.column_stack((np.std(b_matrix[0]), np.std(b_matrix[1]), np.std(b_matrix[2]), np.std(b_matrix[3]), np.std(b_matrix[4]), np.std(b_matrix[5]))) #mod
stdev_b[0][0] = day0_b_stdev
stdev_b_n = stdev_b/bd0_mean
sem_b = stdev_b/(3**0.5)
sem_b[0][0] = day_0_b_sem
sem_b_n = sem_b/bd0_mean
print("stdev_b",stdev_b)

stdev_b_adj = np.column_stack((np.std(b_matrix_adj[0]), np.std(b_matrix_adj[1]), np.std(b_matrix_adj[2]), np.std(b_matrix_adj[3]), np.std(b_matrix_adj[4]), np.std(b_matrix_adj[5]))) #mod
stdev_b_adj[0][0] = day0_b_stdev
stdev_b_n_adj = stdev_b_adj/bd0_mean
sem_b_adj = stdev_b_adj/(2**0.5)
sem_b_adj[0][0] = day_0_b_sem
sem_b_n_adj = sem_b_adj/bd0_mean

print("stdev_c_n", stdev_c_n)
print("stdev_g_n", stdev_g_n)
print("stdev_t_n", stdev_t_n)
print("stdev_b_n", stdev_b_n)
("stdev_g",stdev_g)

stdev_t = np.column_stack((np.std(t_matrix[0]), np.std(t_matrix[1]), np.std(t_matrix[2]), np.std(t_matrix[3]), np.std(t_matrix[4]), np.std(t_matrix[5]), np.std(t_matrix[6]), np.std(t_matrix[7]), np.std(t_matrix[8]))) #mod
stdev_t[0][0] = day0_stdev
stdev_t_n = stdev_t/cgtd0_mean
sem_t = stdev_t/(3**0.5)
sem_t[0][0] = day_0_sem
sem_t_n = sem_t/cgtd0_mean
print("stdev_t",stdev_t)

stdev_b = np.column_stack((np.std(b_matrix[0]), np.std(b_matrix[1]), np.std(b_matrix[2]), np.std(b_matrix[3]), np.std(b_matrix[4]), np.std(b_matrix[5]))) #mod
stdev_b[0][0] = day0_b_stdev
stdev_b_n = stdev_b/bd0_mean
sem_b = stdev_b/(3**0.5)
sem_b[0][0] = day_0_b_sem
sem_b_n = sem_b/bd0_mean
print("stdev_b",stdev_b)

stdev_b_adj = np.column_stack((np.std(b_matrix_adj[0]), np.std(b_matrix_adj[1]), np.std(b_matrix_adj[2]), np.std(b_matrix_adj[3]), np.std(b_matrix_adj[4]), np.std(b_matrix_adj[5]))) #mod
stdev_b_adj[0][0] = day0_b_stdev
stdev_b_n_adj = stdev_b_adj/bd0_mean
sem_b_adj = stdev_b_adj/(2**0.5)
sem_b_adj[0][0] = day_0_b_sem
sem_b_n_adj = sem_b_adj/bd0_mean

print("stdev_c_n", stdev_c_n)
print("stdev_g_n", stdev_g_n)
print("stdev_t_n", stdev_t_n)
print("stdev_b_n", stdev_b_n)
"""
# Out:
# stdev_g5 [6.46813224e+04 3.03108891e+08 4.64279609e+08 3.19178633e+09
#  5.06828373e+09 5.93190526e+08 7.11951543e+09 1.44113670e+09
#  2.16506351e+09 4.33012702e+09 9.22970747e+09] 687386354.243376
# [2.7e+09 2.4e+09 1.6e+09] [3.16427961e+09 2.86427961e+09 2.06427961e+09]
# stdev_max/min 682902280.9459205 418143925.0737217
# gd5: 3676224118.10922 1560756459.9852011 2486111111.0
# gd5_stdev_new: 1057733829.0620095
# ??? (12,) [2200000. 3600000. 3500000. 3300000. 4300000. 3200000. 2600000. 3400000.
#  1800000.  900000. 2200000. 2600000.]
# stdev_c (11,) [6.46813224e+04 8.92561856e+05 1.63322704e+06            nan
#  1.94731290e+08 4.78937618e+08 3.64805444e+08 2.62670081e+08
#  3.19773573e+09 6.54366789e+08 4.11305104e+08]
# sem_c (11,) [2.44472419e+04 2.57660414e+05 4.71472035e+05            nan
#  5.62140813e+07 1.38257381e+08 1.05310261e+08 1.51652642e+08
#  9.23106792e+08 1.88899421e+08 1.18733556e+08]
# stdev_g[2]: 1057733829.0620095
# gd5_stdev_new: 1057733829.0620095
# ...

# %%
plt.figure(figsize=(10, 8))

plt.semilogy(day, c_mean_n, label="c_mean, c2 d7 overgrowth disregarded", color="#AA0000")
plt.errorbar(day, c_mean_n, yerr=sem_c_n, fmt='o', capsize=5, color="#FF0000", alpha=0.4)

plt.semilogy(day, g_mean_n, label="g_mean", color="#00AA00")
plt.errorbar(day, g_mean_n, yerr=sem_g_n, fmt='o', capsize=5, color="#00FF00", alpha=0.4)

plt.semilogy(day, t_mean_n, label="t_mean", color="#0000AA")
plt.errorbar(day, t_mean_n, yerr=sem_t_n, fmt='o', capsize=5, color="#0000FF", alpha=0.4)

plt.semilogy(day_b, b_mean_n, label="b_mean, b10 d4/6/8/11/13/25/39 counted as 0", color="#AA00AA") #mod (label)
plt.errorbar(day_b, b_mean_n, yerr=sem_b_n, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("mean of what is happening, error bars = normalized SEM")
plt.legend(loc='upper left')
plt.show()

# %%
print(c_mean_n_adj)
print(b_mean_n_adj)
plt.figure(figsize=(10, 8))

plt.semilogy(day, c_mean_n_adj, label="c_mean, c2 disregarded", color="#AA0000")
plt.errorbar(day, c_mean_n_adj, yerr=sem_c_n_adj, fmt='o', capsize=5, color="#FF0000", alpha=0.4)

plt.semilogy(day, g_mean_n, label="g_mean", color="#00AA00")
plt.errorbar(day, g_mean_n, yerr=sem_g_n, fmt='o', capsize=5, color="#00FF00", alpha=0.4)

plt.semilogy(day, t_mean_n, label="t_mean", color="#0000AA")
plt.errorbar(day, t_mean_n, yerr=sem_t_n, fmt='o', capsize=5, color="#0000FF", alpha=0.4)

plt.semilogy(day_b, b_mean_n, label="b_mean, b10 d4/6/8/11/13/25/39 counted as 0", color="#AA00AA") #mod (label)
plt.errorbar(day_b, b_mean_n, yerr=sem_b_n, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("c2 (contamination) disregarded, error bars = normalized SEM")
plt.legend(loc='upper left')
plt.show()
# Out:
# [ 1.          6.76442308  5.38461538 16.86057692  8.24519231  7.13461538
#   7.          8.59519231 17.02884615 84.13461538 96.92307692]
# [1.00000000e+00 2.04177917e+01 4.22979167e+01 3.02083333e+01
#  3.50000000e+02 1.89583333e+03 2.29166667e+01 3.23583333e+02]

# %%
"""
plt.figure(figsize=(10, 8))

plt.semilogy(day, c_mean_n, label="c_mean, c2 d7 overgrowth disregarded", color="#AA0000")
plt.errorbar(day, c_mean_n, yerr=stdev_c_n, fmt='o', capsize=5, color="#FF0000", alpha=0.4)

plt.semilogy(day, g_mean_n, label="g_mean", color="#00AA00")
plt.errorbar(day, g_mean_n, yerr=stdev_g_n, fmt='o', capsize=5, color="#00FF00", alpha=0.4)

plt.semilogy(day, t_mean_n, label="t_mean", color="#0000AA")
plt.errorbar(day, t_mean_n, yerr=stdev_t_n, fmt='o', capsize=5, color="#0000FF", alpha=0.4)

plt.semilogy(day_b, b_mean_n, label="b_mean, b10 d4 counted as 0", color="#AA00AA")
plt.errorbar(day_b, b_mean_n, yerr=stdev_b_n, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("what is happening, stdev_x_n")
plt.legend(loc='upper left')
plt.show()
"""

"""
plt.figure(figsize=(10, 8))

plt.semilogy(day, c_mean, label="c_mean, c2 d7 overgrowth disregarded", color="#AA0000")
plt.errorbar(day, c_mean, yerr=sem_c, fmt='o', capsize=5, color="#FF0000", alpha=0.4)

plt.semilogy(day, g_mean, label="g_mean", color="#00AA00")
plt.errorbar(day, g_mean, yerr=sem_g, fmt='o', capsize=5, color="#00FF00", alpha=0.4)

plt.semilogy(day, t_mean, label="t_mean", color="#0000AA")
plt.errorbar(day, t_mean, yerr=sem_t, fmt='o', capsize=5, color="#0000FF", alpha=0.4)

plt.semilogy(day_b, b_mean, label="b_mean, b10 d4 counted as 0", color="#AA00AA")
plt.errorbar(day_b, b_mean, yerr=sem_b, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("what is happening, sem_x")
plt.legend(loc='upper left')
plt.show()
"""

"""
plt.figure(figsize=(10, 8))

plt.semilogy(day, c_mean, label="c_mean, c2 d7 overgrowth disregarded", color="#AA0000")
plt.errorbar(day, c_mean, yerr=stdev_c, fmt='o', capsize=5, color="#FF0000", alpha=0.4)

plt.semilogy(day, g_mean, label="g_mean", color="#00AA00")
plt.errorbar(day, g_mean, yerr=stdev_g, fmt='o', capsize=5, color="#00FF00", alpha=0.4)

plt.semilogy(day, t_mean, label="t_mean", color="#0000AA")
plt.errorbar(day, t_mean, yerr=stdev_t, fmt='o', capsize=5, color="#0000FF", alpha=0.4)

plt.semilogy(day_b, b_mean, label="b_mean, b10 d4 counted as 0", color="#AA00AA")
plt.errorbar(day_b, b_mean, yerr=stdev_b, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("what is happening, stdev_x")
plt.legend(loc='upper left')
plt.show()
"""
# Out:
# '\nplt.figure(figsize=(10, 8))\n\nplt.semilogy(day, c_mean, label="c_mean, c2 d7 overgrowth disregarded", color="#AA0000")\nplt.errorbar(day, c_mean, yerr=stdev_c, fmt=\'o\', capsize=5, color="#FF0000", alpha=0.4)\n\nplt.semilogy(day, g_mean, label="g_mean", color="#00AA00")\nplt.errorbar(day, g_mean, yerr=stdev_g, fmt=\'o\', capsize=5, color="#00FF00", alpha=0.4)\n\nplt.semilogy(day, t_mean, label="t_mean", color="#0000AA")\nplt.errorbar(day, t_mean, yerr=stdev_t, fmt=\'o\', capsize=5, color="#0000FF", alpha=0.4)\n\nplt.semilogy(day_b, b_mean, label="b_mean, b10 d4 counted as 0", color="#AA00AA")\nplt.errorbar(day_b, b_mean, yerr=stdev_b, fmt=\'o\', capsize=5, color="#FF00FF", alpha=0.4)\n\n\nplt.xlabel("Day")\nplt.ylabel("cells.ml^-1 (normalized)")\nplt.title("what is happening, stdev_x")\nplt.legend(loc=\'upper left\')\nplt.show()\n'
