# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import math

cgtbd0 = np.array([13.5E5, 4E5, 7.5E5, 13E5])

c1d1 = np.array([31E5, 33E5, 28E5, 28E5])
c2d1 = np.array([27E5, 30E5, 31E5, 34E5])
c3d1 = np.array([33E5, 42E5, 40E5, 34E5])
g4d1 = np.array([8E6, 13E6, 14E6, 7E6])
g5d1 = np.array([12E6, 12E6, 12E6, 14E6])
g6d1 = np.array([4E6, 6E6, 15E6, 8E6])
t7d1 = np.array([18E5, 9E5, 12E5, 8E5])
t8d1 = np.array([23E5, 14E5, 15E5, 14E5])
t9d1 = np.array([21E5, 17E5, 16E5, 17E5])
b10d1 = np.array([9E2, 15E2, 7E2, 12E2])
b11d1 = np.array([2E2, 1E2, 0, 1E2])
b12d1 = np.array([20E2, 24E2, 28E2, 18E2])

c1d3 = np.array([8E7, 8E7, 8E7, 9E7])
c2d3 = np.array([16E7, 18E7, 14E7, 24E7])
c3d3 = np.array([11E6, 4E6, 6E6, 4E6])
g4d3 = np.array([2E8, 6E8, 5E8, 3E8])
g5d3 = np.array([7E8, 10E8, 7E8, 7E8])
g6d3 = np.array([12E7, 10E7, 7E7, 13E7])
t7d3 = np.array([15E6, 19E6, 12E6, 13E6])
t8d3 = np.array([4E6, 8E6, 3E6, 3E6])
t9d3 = np.array([9E6, 9E6, 12E6, 7E6])
b10d3 = np.array([9E5, 2E5, 10E5, 7E5])
b11d3 = np.array([0, 0, 0, 0])
b12d3 = np.array([47E5, 42E5, 41E5, 47E5])

c1d6 = np.array([6E8, 7E8, 7E8, 8E8])
c2d6 = np.array([39E8, 37E8, 40E8, 37E8])
c3d6 = np.array([23E5, 33E5, 37E5, 31E5])
g4d6 = np.array([105E8, 97E8, 94E8, 111E8])
g5d6 = np.array([8E9, 9E9, 10E9, 10E9])
g6d6 = np.array([9E9, 18E9, 20E9, 11E9])
t7d6 = np.array([15E6, 17E6, 18E6, 27E6])
t8d6 = np.array([18E6, 19E6, 26E6, 28E6])
t9d6 = np.array([33E8, 32E8, 33E8, 25E8])
b10d6 = np.array([15E7, 12E7, 10E7, 8E7])
b11d6 = np.array([0, 0, 0, 0])
b12d6 = np.array([96E8, 91E8, 78E8, 88E8])

c1d8 = np.array([8E8, 9E8, 5E8, 8E8])
c2d8 = np.array([120E7, 166E7, 151E7, 152E7])
c3d8 = np.array([35E5, 29E5, 31E5, 41E5])
g4d8 = np.array([43E8, 40E8, 36E8, 51E8])
g5d8 = np.array([12E9, 4E9, 4E9, 10E9])
g6d8 = np.array([50E8, 49E8, 41E8, 53E8])
t7d8 = np.array([35E6, 33E6, 30E6, 31E6])
t8d8 = np.array([11E7, 14E7, 8E7, 11E7])
t9d8 = np.array([99E8, 80E8, 85E8, 86E8])
b10d8 = np.array([127E7, 151E7, 152E7, 119E7])
b11d8 = np.array([0, 0, 0, 0])
b12d8 = np.array([7E9, 10E9, 5E9, 7E9])

c1d10 = np.array([110E7, 112E7, 110E7, 116E7])
c2d10 = np.array([113E8, 92E8, 98E8, 93E8])
c3d10 = np.array([20E5, 11E5, 20E5, 18E5])
g4d10 = np.array([32E8, 36E8, 46E8, 48E8])
g5d10 = np.array([23E8, 15E8, 24E8, 17E8])
g6d10 = np.array([25E8, 21E8, 24E8, 15E8])
t7d10 = np.array([27E6, 37E6, 24E6, 30E6])
t8d10 = np.array([11E8, 11E8, 10E8, 9E8])
t9d10 = np.array([121E8, 108E8, 94E8, 107E8])
b10d10 = np.array([65E7, 56E7, 75E7, 59E7])
b11d10 = np.array([0, 0, 0, 0])
b12d10 = np.array([38E9, 36E9, 42E9, 37E9])

c1d13 = np.array([201E9, 146E9, 171E9, 187E9])
c2d13 = np.array([133E9, 111E9, 146E9, 105E9])
c3d13 = np.array([1E5, 0E5, 2E5, 1E5])
g4d13 = np.array([22E8, 18E8, 17E8, 22E8])
g5d13 = np.array([31E9, 37E9, 29E9, 25E9])
g6d13 = np.array([22E8, 25E8, 21E8, 27E8])
t7d13 = np.array([10E7, 9E7, 4E7, 7E7])
t8d13 = np.array([25E8, 26E8, 38E8, 29E8])
t9d13 = np.array([13E9, 13E9, 18E9, 15E9])
b10d13 = np.array([359E7, 366E7, 370E7, 394E7])
b11d13 = np.array([0, 0, 0, 0])
b12d13 = np.array([58E8, 38E8, 65E8, 59E8])

#mod

cgtbd0_mean = np.mean(cgtbd0)

c1d1_mean = np.mean(c1d1)
c2d1_mean = np.mean(c2d1)
c3d1_mean = np.mean(c3d1)
g4d1_mean = np.mean(g4d1)
g5d1_mean = np.mean(g5d1)
g6d1_mean = np.mean(g6d1)
t7d1_mean = np.mean(t7d1)
t8d1_mean = np.mean(t8d1)
t9d1_mean = np.mean(t9d1)
b10d1_mean = np.mean(b10d1)
b11d1_mean = np.mean(b11d1)
b12d1_mean = np.mean(b12d1)

c1d3_mean = np.mean(c1d3)
c2d3_mean = np.mean(c2d3)
c3d3_mean = np.mean(c3d3)
g4d3_mean = np.mean(g4d3)
g5d3_mean = np.mean(g5d3)
g6d3_mean = np.mean(g6d3)
t7d3_mean = np.mean(t7d3)
t8d3_mean = np.mean(t8d3)
t9d3_mean = np.mean(t9d3)
b10d3_mean = np.mean(b10d3)
b11d3_mean = np.mean(b11d3)
b12d3_mean = np.mean(b12d3)

c1d6_mean = np.mean(c1d6)
c2d6_mean = np.mean(c2d6)
c3d6_mean = np.mean(c3d6)
g4d6_mean = np.mean(g4d6)
g5d6_mean = np.mean(g5d6)
g6d6_mean = np.mean(g6d6)
t7d6_mean = np.mean(t7d6)
t8d6_mean = np.mean(t8d6)
t9d6_mean = np.mean(t9d6)
b10d6_mean = np.mean(b10d6)
b11d6_mean = np.mean(b11d6)
b12d6_mean = np.mean(b12d6)

c1d8_mean = np.mean(c1d8)
c2d8_mean = np.mean(c2d8)
c3d8_mean = np.mean(c3d8)
g4d8_mean = np.mean(g4d8)
g5d8_mean = np.mean(g5d8)
g6d8_mean = np.mean(g6d8)
t7d8_mean = np.mean(t7d8)
t8d8_mean = np.mean(t8d8)
t9d8_mean = np.mean(t9d8)
b10d8_mean = np.mean(b10d8)
b11d8_mean = np.mean(b11d8)
b12d8_mean = np.mean(b12d8)

c1d10_mean = np.mean(c1d10)
c2d10_mean = np.mean(c2d10)
c3d10_mean = np.mean(c3d10)
g4d10_mean = np.mean(g4d10)
g5d10_mean = np.mean(g5d10)
g6d10_mean = np.mean(g6d10)
t7d10_mean = np.mean(t7d10)
t8d10_mean = np.mean(t8d10)
t9d10_mean = np.mean(t9d10)
b10d10_mean = np.mean(b10d10)
b11d10_mean = np.mean(b11d10)
b12d10_mean = np.mean(b12d10)

c1d13_mean = np.mean(c1d13)
c2d13_mean = np.mean(c2d13)
c3d13_mean = np.mean(c3d13)
g4d13_mean = np.mean(g4d13)
g5d13_mean = np.mean(g5d13)
g6d13_mean = np.mean(g6d13)
t7d13_mean = np.mean(t7d13)
t8d13_mean = np.mean(t8d13)
t9d13_mean = np.mean(t9d13)
b10d13_mean = np.mean(b10d13)
b11d13_mean = np.mean(b11d13)
b12d13_mean = np.mean(b12d13)

#mod

# %%
c1 = np.array([cgtbd0_mean, c1d1_mean, c1d3_mean, c1d6_mean, c1d8_mean, c1d10_mean, c1d13_mean]) #mod
c1n = c1/cgtbd0_mean
c2 = np.array([cgtbd0_mean, c2d1_mean, c2d3_mean, c2d6_mean, c2d8_mean, c2d10_mean, c2d13_mean])  #mod    
c2n = c2/cgtbd0_mean
c3 = np.array([cgtbd0_mean, c3d1_mean, c3d3_mean, c3d6_mean, c3d8_mean, c3d10_mean, c3d13_mean])  #mod
c3n = c3/cgtbd0_mean

g4 = np.array([cgtbd0_mean, g4d1_mean, g4d3_mean, g4d6_mean, g4d8_mean, g4d10_mean, g4d13_mean]) #mod
g4n = g4/cgtbd0_mean
g5 = np.array([cgtbd0_mean, g5d1_mean, g5d3_mean, g5d6_mean, g5d8_mean, g5d10_mean, g5d13_mean]) #mod    
g5n = g5/cgtbd0_mean
g6 = np.array([cgtbd0_mean, g6d1_mean, g6d3_mean, g6d6_mean, g6d8_mean, g6d10_mean, g6d13_mean]) #mod
g6n = g6/cgtbd0_mean

t7 = np.array([cgtbd0_mean, t7d1_mean, t7d3_mean, t7d6_mean, t7d8_mean, t7d10_mean, t7d13_mean]) #mod
t7n = t7/cgtbd0_mean
t8 = np.array([cgtbd0_mean, t8d1_mean, t8d3_mean, t8d6_mean, t8d8_mean, t8d10_mean, t8d13_mean]) #mod
t8n = t8/cgtbd0_mean
t9 = np.array([cgtbd0_mean, t9d1_mean, t9d3_mean, t9d6_mean, t9d8_mean, t9d10_mean, t9d13_mean]) #mod
t9n = t9/cgtbd0_mean

b10 = np.array([cgtbd0_mean, b10d1_mean, b10d3_mean, b10d6_mean, b10d8_mean, b10d10_mean, b10d13_mean]) #mod
b10n = b10/cgtbd0_mean
b11 = np.array([cgtbd0_mean, b11d1_mean, b11d3_mean, b11d6_mean, b11d8_mean, b11d10_mean, b11d13_mean]) #mod
b11n = b11/cgtbd0_mean
b11n[2] = np.nan
b12 = np.array([cgtbd0_mean, b12d1_mean, b12d3_mean, b12d6_mean, b12d8_mean, b12d10_mean, b12d13_mean]) #mod
b12n = b12/cgtbd0_mean

# %%
import statistics

day0_stdev = np.std(cgtbd0)

day_0_sem = day0_stdev/(4**0.5)
print(day0_stdev)


stdev_c1 = np.array([day0_stdev, np.std(c1d1), np.std(c1d3), np.std(c1d6), np.std(c1d8), np.std(c1d10), np.std(c1d13)])
stdev_c2 = np.array([day0_stdev, np.std(c2d1), np.std(c2d3), np.std(c2d6), np.std(c2d8), np.std(c2d10), np.std(c2d13)])
stdev_c3 = np.array([day0_stdev, np.std(c3d1), np.std(c3d3), np.std(c3d6), np.std(c3d8), np.std(c3d10), np.std(c3d13)])
stdev_g4 = np.array([day0_stdev, np.std(g4d1), np.std(g4d3), np.std(g4d6), np.std(g4d8), np.std(g4d10), np.std(g4d13)])
stdev_g5 = np.array([day0_stdev, np.std(g5d1), np.std(g5d3), np.std(g5d6), np.std(g5d8), np.std(g5d10), np.std(g5d13)])
stdev_g6 = np.array([day0_stdev, np.std(g6d1), np.std(g6d3), np.std(g6d6), np.std(g6d8), np.std(g6d10), np.std(g6d13)])
stdev_t7 = np.array([day0_stdev, np.std(t7d1), np.std(t7d3), np.std(t7d6), np.std(t7d8), np.std(t7d10), np.std(t7d13)])
stdev_t8 = np.array([day0_stdev, np.std(t8d1), np.std(t8d3), np.std(t8d6), np.std(t8d8), np.std(t8d10), np.std(t8d13)])
stdev_t9 = np.array([day0_stdev, np.std(t9d1), np.std(t9d3), np.std(t9d6), np.std(t9d8), np.std(t9d10), np.std(t9d13)])
stdev_b10 = np.array([day0_stdev, np.std(b10d1), np.std(b10d3), np.std(b10d6), np.std(b10d8), np.std(b10d10), np.std(b10d13)])
stdev_b11 = np.array([day0_stdev, np.std(b11d1), np.std(b11d3), np.std(b11d6), np.std(b11d8), np.std(b11d10), np.std(b11d13)])
stdev_b12 = np.array([day0_stdev, np.std(b12d1), np.std(b12d3), np.std(b12d6), np.std(b12d8), np.std(b12d10), np.std(b12d13)])

#mod all of above

sem_c1 = stdev_c1/(4**0.5)
sem_c2 = stdev_c2/(4**0.5)
sem_c3 = stdev_c3/(4**0.5)
sem_g4 = stdev_g4/(4**0.5)
sem_g5 = stdev_g5/(4**0.5)
sem_g6 = stdev_g6/(4**0.5)
sem_t7 = stdev_t7/(4**0.5)
sem_t8 = stdev_t8/(4**0.5)
sem_t9 = stdev_t9/(4**0.5)
sem_b10 = stdev_b10/(4**0.5)
sem_b11 = stdev_b11/(4**0.5)
sem_b12 = stdev_b12/(4**0.5)

sem_c1_n = sem_c1/cgtbd0_mean
sem_c2_n = sem_c2/cgtbd0_mean
sem_c3_n = sem_c3/cgtbd0_mean
sem_g4_n = sem_g4/cgtbd0_mean
sem_g5_n = sem_g5/cgtbd0_mean
sem_g6_n = sem_g6/cgtbd0_mean
sem_t7_n = sem_t7/cgtbd0_mean
sem_t8_n = sem_t8/cgtbd0_mean
sem_t9_n = sem_t9/cgtbd0_mean
sem_b10_n = sem_b10/cgtbd0_mean
sem_b11_n = sem_b11/cgtbd0_mean
sem_b12_n = sem_b12/cgtbd0_mean

print('stdev g4', np.shape(stdev_g4), stdev_g4)
print('sem c1', np.shape(sem_c1), sem_c1)
print('sem_n c1', np.shape(sem_c1_n), sem_c1_n)
# Out:
# 395284.70752104744
# stdev g4 (7,) [3.95284708e+05 3.04138127e+06 1.58113883e+08 6.68487098e+08
#  5.50000000e+08 6.68954408e+08 2.27760839e+08]
# sem c1 (7,) [1.97642354e+05 1.06066017e+05 2.16506351e+06 3.53553391e+07
#  7.50000000e+07 1.22474487e+07 1.02187022e+10]
# sem_n c1 (7,) [2.08044583e-01 1.11648439e-01 2.27901422e+00 3.72161464e+01
#  7.89473684e+01 1.28920513e+01 1.07565286e+04]

# %%
day = np.array([0, 1, 3, 6, 8, 10, 13]) #mod

plt.figure(figsize=(10, 8))
plt.semilogy(day, c1n, label="c1", color="#FF0000")
plt.errorbar(day, c1n, yerr=sem_c1_n, fmt='o', capsize=5, color="#FF0000", alpha=0.4)
plt.semilogy(day, c2n, label="c2", color="#AA0000")
plt.errorbar(day, c2n, yerr=sem_c2_n, fmt='o', capsize=5, color="#AA0000", alpha=0.4)
plt.semilogy(day, c3n, label="c3", color="#660000")
plt.errorbar(day, c3n, yerr=sem_c3_n, fmt='o', capsize=5, color="#660000", alpha=0.4)

plt.semilogy(day, g4n, label="g4", color="#00FF00")
plt.errorbar(day, g4n, yerr=sem_g4_n, fmt='o', capsize=5, color="#00FF00", alpha=0.4)
plt.semilogy(day, g5n, label="g5", color="#00AA00")
plt.errorbar(day, g5n, yerr=sem_g5_n, fmt='o', capsize=5, color="#00AA00", alpha=0.4)
plt.semilogy(day, g6n, label="g6", color="#006600")
plt.errorbar(day, g6n, yerr=sem_g6_n, fmt='o', capsize=5, color="#006600", alpha=0.4)

plt.semilogy(day, t7n, label="t7", color="#0000FF")
plt.errorbar(day, t7n, yerr=sem_t7_n, fmt='o', capsize=5, color="#0000FF", alpha=0.4)
plt.semilogy(day, t8n, label="t8", color="#0000AA")
plt.errorbar(day, t8n, yerr=sem_t8_n, fmt='o', capsize=5, color="#0000AA", alpha=0.4)
plt.semilogy(day, t9n, label="t9", color="#000066")
plt.errorbar(day, t9n, yerr=sem_t9_n, fmt='o', capsize=5, color="#000066", alpha=0.4)

plt.semilogy(day, b10n, label="b10", color="#FF00FF")
plt.errorbar(day, b10n, yerr=sem_b10_n, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)
plt.semilogy(day, b11n, label="b11, d3=0", color="#AA00AA")
plt.errorbar(day, b11n, yerr=sem_b11_n, fmt='o', capsize=5, color="#AA00AA", alpha=0.4)
plt.semilogy(day, b12n, label="b12", color="#660066")
plt.errorbar(day, b12n, yerr=sem_b12_n, fmt='o', capsize=5, color="#660066", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("what is happening, CII")
plt.legend(loc='upper left')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))

axs[0, 0].plot(day, c1, label="c1", color="#FF0000")
axs[0, 0].plot(day, c2, label="c2", color="#AA0000")
axs[0, 0].plot(day, c3, label="c3", color="#660000")
axs[0, 0].set_title("control")
axs[0, 0].errorbar(day, c1, yerr=sem_c1, fmt='o', capsize=5, color="#FF0000", alpha=0.4)
axs[0, 0].errorbar(day, c2, yerr=sem_c1, fmt='o', capsize=5, color="#AA0000", alpha=0.4)
axs[0, 0].errorbar(day, c3, yerr=sem_c3, fmt='o', capsize=5, color="#660000", alpha=0.4)

axs[1, 0].plot(day, g4, label="g4", color="#00FF00")
axs[1, 0].plot(day, g5, label="g5", color="#00AA00")
axs[1, 0].plot(day, g6, label="g6", color="#006600")
axs[1, 0].set_title("glucose")
axs[1, 0].errorbar(day, g4, yerr=sem_g4, fmt='o', capsize=5, color="#00FF00", alpha=0.4)
axs[1, 0].errorbar(day, g5, yerr=sem_g5, fmt='o', capsize=5, color="#00AA00", alpha=0.4)
axs[1, 0].errorbar(day, g6, yerr=sem_g6, fmt='o', capsize=5, color="#006600", alpha=0.4)

axs[0, 1].plot(day, t7, label="t7", color="#0000FF")
axs[0, 1].plot(day, t8, label="t8", color="#0000AA")
axs[0, 1].plot(day, t9, label="t9", color="#000066")
axs[0, 1].set_title("tholins")
axs[0, 1].errorbar(day, t7, yerr=sem_t7, fmt='o', capsize=5, color="#0000FF", alpha=0.4)
axs[0, 1].errorbar(day, t8, yerr=sem_t8, fmt='o', capsize=5, color="#0000AA", alpha=0.4)
axs[0, 1].errorbar(day, t9, yerr=sem_t9, fmt='o', capsize=5, color="#000066", alpha=0.4)

axs[1, 1].plot(day, b10, label="b10", color="#FF00FF")
axs[1, 1].plot(day, b11, label="b11", color="#AA00AA")
axs[1, 1].plot(day, b12, label="b12", color="#660066")
axs[1, 1].set_title("baked moon")
axs[1, 1].errorbar(day, b10, yerr=sem_b10, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)
axs[1, 1].errorbar(day, b11, yerr=sem_b11, fmt='o', capsize=5, color="#AA00AA", alpha=0.4)
axs[1, 1].errorbar(day, b12, yerr=sem_b12, fmt='o', capsize=5, color="#660066", alpha=0.4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def mean_of_arrays (a,b,c):
    mean_arr = np.array([(a[i]+b[i]+c[i])/3 for i in range (len(a))])
    return mean_arr

def mean_of_arrays_adj (a,b):
    mean_arr_adj = np.array([(a[i]+b[i])/2 for i in range (len(a))])
    return mean_arr_adj

c_mean = mean_of_arrays(c1,c2,c3)
c_mean_n = c_mean/cgtbd0_mean

g_mean = mean_of_arrays(g4,g5,g6)
g_mean_n = g_mean/cgtbd0_mean

t_mean = mean_of_arrays(t7,t8,t9)
t_mean_n = t_mean/cgtbd0_mean

b_mean = mean_of_arrays(b10,b11,b12)
b_mean_n = b_mean/cgtbd0_mean

print(c_mean, g_mean, t_mean, b_mean)
# Out:
# [9.50000000e+05 3.25833333e+06 8.95833333e+07 1.50936667e+09
#  7.41966667e+08 3.67390833e+09 1.00000033e+11] [9.50000000e+05 1.04166667e+07 4.26666667e+08 1.13083333e+10
#  5.52500000e+09 2.71666667e+09 1.16166667e+10] [9.50000000e+05 1.53333333e+06 9.50000000e+06 1.03900000e+09
#  2.96408333e+09 3.93483333e+09 5.92500000e+09] [9.50000000e+05 1.14166667e+03 1.70833333e+06 2.97916667e+09
#  2.87416667e+09 1.29625000e+10 3.07416667e+09]

# %%
cd1_comb = np.concatenate((c1d1, c2d1, c3d1))
gd1_comb = np.concatenate((g4d1, g5d1, g6d1))
td1_comb = np.concatenate((t7d1, t8d1, t9d1))
bd1_comb = np.concatenate((b10d1, b11d1, b12d1))

cd3_comb = np.concatenate((c1d3, c2d3, c3d3))
gd3_comb = np.concatenate((g4d3, g5d3, g6d3))
td3_comb = np.concatenate((t7d3, t8d3, t9d3))
bd3_comb = np.concatenate((b10d3, b11d3, b12d3))

cd6_comb = np.concatenate((c1d6, c2d6, c3d6))
gd6_comb = np.concatenate((g4d6, g5d6, g6d6))
td6_comb = np.concatenate((t7d6, t8d6, t9d6))
bd6_comb = np.concatenate((b10d6, b11d6, b12d6))

cd8_comb = np.concatenate((c1d8, c2d8, c3d8))
gd8_comb = np.concatenate((g4d8, g5d8, g6d8))
td8_comb = np.concatenate((t7d8, t8d8, t9d8))
bd8_comb = np.concatenate((b10d8, b11d8, b12d8))

cd10_comb = np.concatenate((c1d10, c2d10, c3d10))
gd10_comb = np.concatenate((g4d10, g5d10, g6d10))
td10_comb = np.concatenate((t7d10, t8d10, t9d10))
bd10_comb = np.concatenate((b10d10, b11d10, b12d10))

cd13_comb = np.concatenate((c1d13, c2d13, c3d13))
gd13_comb = np.concatenate((g4d13, g5d13, g6d13))
td13_comb = np.concatenate((t7d13, t8d13, t9d13))
bd13_comb = np.concatenate((b10d13, b11d13, b12d13))

#mod


stdev_c = np.array([day0_stdev, np.std(cd1_comb), np.std(cd3_comb), np.std(cd6_comb), np.std(cd8_comb), np.std(cd10_comb), np.std(cd13_comb)])#mod
stdev_g = np.array([day0_stdev, np.std(gd1_comb), np.std(gd3_comb), np.std(gd6_comb), np.std(gd8_comb), np.std(gd10_comb), np.std(gd13_comb)])#mod
stdev_t = np.array([day0_stdev, np.std(td1_comb), np.std(td3_comb), np.std(td6_comb), np.std(td8_comb), np.std(td10_comb), np.std(td13_comb)])#mod
stdev_b = np.array([day0_stdev, np.std(bd1_comb), np.std(bd3_comb), np.std(bd6_comb), np.std(bd8_comb), np.std(bd10_comb), np.std(bd13_comb)])#mod

sem_c = stdev_c/(12**0.5)
sem_c[0] = day_0_sem
sem_g = stdev_g/(12**0.5)   
sem_g[0] = day_0_sem
sem_t = stdev_t/(12**0.5)
sem_t[0] = day_0_sem
sem_b = stdev_b/(12**0.5)
sem_b[0] = day_0_sem

sem_c_n = sem_c/cgtbd0_mean
sem_g_n = sem_g/cgtbd0_mean
sem_t_n = sem_t/cgtbd0_mean
sem_b_n = sem_b/cgtbd0_mean

# %%
plt.figure(figsize=(10, 8))

plt.semilogy(day, c_mean_n, label="c_mean", color="#AA0000")
plt.errorbar(day, c_mean_n, yerr=sem_c_n, fmt='o', capsize=5, color="#FF0000", alpha=0.4)

plt.semilogy(day, g_mean_n, label="g_mean", color="#00AA00")
plt.errorbar(day, g_mean_n, yerr=sem_g_n, fmt='o', capsize=5, color="#00FF00", alpha=0.4)

plt.semilogy(day, t_mean_n, label="t_mean", color="#0000AA")
plt.errorbar(day, t_mean_n, yerr=sem_t_n, fmt='o', capsize=5, color="#0000FF", alpha=0.4)

plt.semilogy(day, b_mean_n, label="b_mean", color="#AA00AA")
plt.errorbar(day, b_mean_n, yerr=sem_b_n, fmt='o', capsize=5, color="#FF00FF", alpha=0.4)


plt.xlabel("Day")
plt.ylabel("cells.ml^-1 (normalized)")
plt.title("mean of what is happening, isolate,  error bars = normalized SEM")
plt.legend(loc='upper left')
plt.show()
